# %%
x = 15
y = 15.1
z = "hello"
print(x)
print(y)
print(z)
# Out:
# 15
# 15.1
# hello

# %% [markdown]
# #### I created 3 variables. Their names are x, y, and z. x is an integer, y is a float, and z is a string. I used the print command to print them.

# %%
jar1 = 5
jar2 = 10
hello = "hello"
print(jar1 + jar2 + hello)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 jar2 = 10
#       3 hello = "hello"
# ----> 4 print(jar1 + jar2 + hello)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# #### The fourth command causes an error. This is because you cannot add strings to integers.

# %%
jar1 = 5
jar2 = 10
print(jar2)

jar2 = jar1
print(jar2)
# Out:
# 10
# 5

# %% [markdown]
# #### You can overwrite values. Whatever is on the left on the equal sign gets set to whats on the right.

# %%
name = "John"
age = 8
print("My name is",name,"and I am",age,"years old!")
# Out:
# My name is John and I am 8 years old!

# %% [markdown]
# #### Strings and variables are able to be combined in a print statement with commas.

# %%
my_name = "Phelo beshay"
print(my_name.upper())
print(my_name.lower())
print(my_name.title())
# Out:
# PHELO BESHAY
# phelo beshay
# Phelo Beshay

# %% [markdown]
# #### Functions are different from methods. Print is a function and can be used by itself by editing what is in the parenthesis. Methods must be called on and require parenthesis after. Examples of methods are upper (makes everything uppercase), lower (makes everything lowercase) and title (capitalizes the first letter in every word).

# %%
my_life = "focusing is challenging, procrastination is easy"
print(my_life.title())
# Out:
# Focusing Is Challenging, Procrastination Is Easy
