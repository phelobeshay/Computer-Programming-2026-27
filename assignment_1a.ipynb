# %% [markdown]
# # Beshay, Phelopatir
# # Computer Programming, Period 4
# # Assignment: Homework 1
# # August 27 2026

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello my name is Phelo Beshay!")
# Out:
# Hello my name is Phelo Beshay!

# %%
print("I love python!")
# Out:
# I love python!

# %%
print("16")
# Out:
# 16

# %%
print(5+5)
# Out:
# 10

# %%
print(4*3)
# Out:
# 12

# %%
print(50-40)
# Out:
# 10

# %%
print(100/5)
print(100//5)
# Out:
# 20.0
# 20

# %% [markdown]
# #### explain the difference
